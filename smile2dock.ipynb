# %% [markdown]
# <a href="https://colab.research.google.com/github/Sbolivar16/MolecularDocking/blob/main/smile2dock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 Welcome to the SMILES-to-3D Docking Notebook!
#
# <div align="center">
#
# 🧪 **Santiago Bolívar A.**
# **Qco., M.Sc., Ph.D.**
# 📍 *National University of Rosario, Argentina*
# 🔗 [GitHub Profile](https://github.com/Sbolivar16)
#
# </div>
#
# Welcome! This notebook is designed to guide you through an interactive journey from **SMILES strings** to **3D molecular structures** ready for docking simulations (SDF · PDB · PDBQT). 🎯
#
# Inspired by the fantastic work of **[@elvismartis](https://github.com/elvismartis)** with the [**smile2dock**](https://github.com/elvismartis/smile2dock) repository, this notebook makes the process:
#
# - 🔄 **Easy to run** — just a few commands!
# - 🌡 **Customizable pH protonation**
# - 🧬 **Molecular similarity** comparison with Tanimoto
# - 🔁 **Batch processing** of multiple molecules
#
# Whether you're a student learning cheminformatics or a researcher preparing ligands for docking, this notebook offers clear, commented steps to support your workflow.
#
# ---
#
# Ready to explore? Let's dive in! 🧪

# %%
# !git clone https://github.com/elvismartis/smile2dock.git
# %cd smile2dock
# !pip install rdkit-pypi openbabel-wheel pybel dimorphite_dl
# Out:
# Cloning into 'smile2dock'...
# remote: Enumerating objects: 228, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 228 (delta 26), reused 13 (delta 12), pack-reused 191 (from 1)
# Receiving objects: 100% (228/228), 2.08 MiB | 11.05 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# /content/smile2dock
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting openbabel-wheel
#   Downloading openbabel_wheel-3.1.1.22-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pybel
#   Downloading pybel-0.15.5-py3-none-any.whl.metadata (19 kB)
# Collecting dimorphite_dl
#   Downloading dimorphite_dl-2.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit-pypi) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit-pypi) (11.2.1)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from pybel) (3.5)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.11/dist-packages (from pybel) (2.0.41)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from pybel) (8.2.1)
# Collecting click-plugins (from pybel)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting bel-resources>=0.0.3 (from pybel)
#   Downloading bel_resources-0.0.3-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from pybel) (10.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pybel) (2.32.3)
# Collecting requests-file (from pybel)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from pybel) (3.2.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from pybel) (4.67.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from pybel) (4.12.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from pybel) (0.9.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pybel) (2.2.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from pybel) (4.24.0)
# Collecting bioregistry (from pybel)
#   Downloading bioregistry-0.12.19-py3-none-any.whl.metadata (35 kB)
# Collecting ratelimit (from pybel)
#   Downloading ratelimit-2.2.1.tar.gz (5.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pystow>=0.1.2 (from pybel)
#   Downloading pystow-0.7.1-py3-none-any.whl.metadata (17 kB)
# Collecting psycopg2-binary (from pybel)
#   Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting loguru<0.8,>=0.7.2 (from dimorphite_dl)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting rdkit<2026,>=2020.3.3 (from dimorphite_dl)
#   Downloading rdkit-2025.3.3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Collecting multisplitby (from bel-resources>=0.0.3->pybel)
#   Downloading multisplitby-0.0.1-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pystow>=0.1.2->pybel) (4.14.0)
# Collecting more_click>=0.1.2 (from bioregistry->pybel)
#   Downloading more_click-0.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.11/dist-packages (from pydantic[email]>=2.0->bioregistry->pybel) (2.11.7)
# Collecting curies>=0.7.0 (from bioregistry->pybel)
#   Downloading curies-0.10.19-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema->pybel) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->pybel) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->pybel) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->pybel) (0.25.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pybel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pybel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pybel) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pybel) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pybel) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pybel) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pybel) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->pybel) (3.2.3)
# Collecting pytrie (from curies>=0.7.0->bioregistry->pybel)
#   Downloading PyTrie-0.4.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->pydantic[email]>=2.0->bioregistry->pybel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->pydantic[email]>=2.0->bioregistry->pybel) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->pydantic[email]>=2.0->bioregistry->pybel) (0.4.1)
# Collecting email-validator>=2.0.0 (from pydantic[email]>=2.0->bioregistry->pybel)
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pybel) (1.17.0)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->pydantic[email]>=2.0->bioregistry->pybel)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from pytrie->curies>=0.7.0->bioregistry->pybel) (2.4.0)
# Downloading rdkit_pypi-2022.9.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 30.1 MB/s eta 0:00:00
# Downloading openbabel_wheel-3.1.1.22-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 84.0 MB/s eta 0:00:00
# Downloading pybel-0.15.5-py3-none-any.whl (387 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.8/387.8 kB 27.5 MB/s eta 0:00:00
# Downloading dimorphite_dl-2.0.1-py3-none-any.whl (39 kB)
# Downloading bel_resources-0.0.3-py3-none-any.whl (17 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.0 MB/s eta 0:00:00
# Downloading pystow-0.7.1-py3-none-any.whl (39 kB)
# Downloading rdkit-2025.3.3-cp311-cp311-manylinux_2_28_x86_64.whl (34.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 20.8 MB/s eta 0:00:00
# Downloading bioregistry-0.12.19-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 93.1 MB/s eta 0:00:00
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 82.9 MB/s eta 0:00:00
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Downloading curies-0.10.19-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 4.8 MB/s eta 0:00:00
# Downloading more_click-0.1.2-py3-none-any.whl (6.7 kB)
# Downloading multisplitby-0.0.1-py3-none-any.whl (4.0 kB)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading PyTrie-0.4.0-py3-none-any.whl (6.1 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 24.8 MB/s eta 0:00:00
# Building wheels for collected packages: ratelimit
#   Building wheel for ratelimit (setup.py) ... done
#   Created wheel for ratelimit: filename=ratelimit-2.2.1-py3-none-any.whl size=5893 sha256=99cea48a0ccb4e65fb1416b9aa456fb29b59a6ea137ab3b38401e1693a4cffdf
#   Stored in directory: /root/.cache/pip/wheels/ee/d5/e5/8fbffe089140fb498987b7709becf861086daace105d243475
# Successfully built ratelimit
# Installing collected packages: ratelimit, rdkit-pypi, rdkit, pytrie, psycopg2-binary, openbabel-wheel, multisplitby, more_click, loguru, dnspython, click-plugins, requests-file, pystow, email-validator, dimorphite_dl, curies, bel-resources, bioregistry, pybel
# Successfully installed bel-resources-0.0.3 bioregistry-0.12.19 click-plugins-1.1.1 curies-0.10.19 dimorphite_dl-2.0.1 dnspython-2.7.0 email-validator-2.2.0 loguru-0.7.3 more_click-0.1.2 multisplitby-0.0.1 openbabel-wheel-3.1.1.22 psycopg2-binary-2.9.10 pybel-0.15.5 pystow-0.7.1 pytrie-0.4.0 ratelimit-2.2.1 rdkit-2025.3.3 rdkit-pypi-2022.9.5 requests-file-2.1.0

# %%
# !python smile2dock.py -i "CCO" -o ethanol
# Out:
# Generated files: ['ethanol.pdb', 'ethanol.mol2', 'ethanol.sdf', 'ethanol.pdbqt']
#
# Molecular Properties:
# Molecular Weight: 46.04
# Crippen_LogP: -0.00
# Crippen_MR: 12.76
# H-Bond Donors: 1.00
# H-Bond Acceptors: 1.00
# TPSA: 20.23
# Rotatable Bonds: 2.00
# #Aliphatic Rings: 0.00
# #Aromatic Rings: 0.00
# #Heteroaromatic Rings: 0.00

# %% [markdown]
# ## 📘 Description of Common smile2dock Commands
#
# Below is a list of commonly used `smile2dock` commands with a brief explanation of what each one does:
#
# ---
#
# ### 🔹 Single Molecule Conversion
#
# ```bash
# !python3 smile2dock.py -i "CCO" -o ethanol
# ```
#
# Description:
# Converts the input SMILES (CCO, ethanol) into 3D structure files (.sdf, .pdb, and .pdbqt).
# The output files will be named based on the -o argument (ethanol).
#
# ---
# ### 🔹 Single Molecule Conversion
# ```bash
# !python3 smile2dock.py -i "CCO" --protonate --ph_min 7.4 --ph_max 7.4 -o ethanol
# ```
# Description:
# Performs 3D conversion and adjusts the protonation state of the molecule at a given pH (7.4 in this case) using dimorphite_dl.
# Useful for preparing molecules under physiological pH conditions.
#
# ---
#
# ### 🔹Single Molecule Conversion with Tanimoto Similarity
#
# ```bash
# !python3 smile2dock.py -i "CCO" -o ethanol --reference "CCN"
# ```
#
# Description:
# Generates 3D structure for CCO and compares its molecular fingerprint with a reference SMILES (CCN).
# Outputs the Tanimoto similarity value between the two molecules.
#
# ---
#
# ### 🔹Batch Processing for Molecular Conversion
#
# ```bash
# !python3 smile2dock.py -i molecules.smi -o output_directory
# ```
#
# Description:
# Processes a list of SMILES in the file molecules.smi (one per line) and generates 3D structures for each.
# Output files are stored in the specified folder output_directory.
#
# Example content of molecules.smi:
#
# CCO ethanol
#
# CCN ethylamine
#
# ---
#
# ### 🔹Batch Processing with Protonation
#
# ```bash
# !python3 smile2dock.py -i molecules.smi --protonate --ph_min 7.4 --ph_max 7.4 -o output_directory
# ```
#
# Description:
# Performs batch 3D conversion with protonation at pH 7.4 for each molecule listed in molecules.smi.
# Results are stored in output_directory.
#
# ---

# %% [markdown]
# ## 🧪 About This Notebook
#
# This Google Colab notebook was created as an educational interface inspired by the excellent repository:
# **[smile2dock](https://github.com/elvismartis/smile2dock)** by [@elvismartis](https://github.com/elvismartis).
#
# The goal of this notebook is to make the usage of `smile2dock.py` more accessible for students and researchers by providing an interactive, step-by-step environment for converting SMILES to docking-ready 3D formats (SDF, PDB, PDBQT).
#
# ### 📚 Citation
#
# If you use this tool for your work, please consider citing the following:
#
# > Martis, E. A. (2023). *smile2dock: Python script to convert SMILES to dockable 3D structures*. GitHub repository.
# > [https://github.com/elvismartis/smile2dock](https://github.com/elvismartis/smile2dock)
